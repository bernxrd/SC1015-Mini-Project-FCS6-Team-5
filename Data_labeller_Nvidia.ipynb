# %%
import pandas as pd

# Load the Excel file to see its content and structure
file_path = r"C:\Users\raysh\OneDrive - Nanyang Technological University\Year 1 Sem 2\SC1015 Intro to Data Sci and AI\Mini Project\Nvidia Data\Updated_GPU_Dataset279_Nvidia.xlsx"
gpu_data = pd.read_excel(file_path)

# Display the first few rows of the dataframe to understand its structure
gpu_data.head()
# Out:
#   Manufacturer   Generation                Product Name  \
# 0       Nvidia  GeForce 100            GeForce G100 OEM
# 1       Nvidia  GeForce 100          GeForce GT 120 OEM
# 2       Nvidia  GeForce 100  GeForce GT 120 Mac Edition
# 3       Nvidia  GeForce 100          GeForce GT 130 OEM
# 4       Nvidia  GeForce 100  GeForce GT 130 Mac Edition
#
#                                              GPU URL GPU Chip  \
# 0  https://www.techpowerup.com/gpu-specs/geforce-...     G98S
# 1  https://www.techpowerup.com/gpu-specs/geforce-...     G96C
# 2  https://www.techpowerup.com/gpu-specs/geforce-...     G96C
# 3  https://www.techpowerup.com/gpu-specs/geforce-...     G94B
# 4  https://www.techpowerup.com/gpu-specs/geforce-...     G94B
#
#                                             Chip URL        Released    Year  \
# 0  https://www.techpowerup.com/gpu-specs/nvidia-g...  Mar 10th, 2009  2009.0
# 1  https://www.techpowerup.com/gpu-specs/nvidia-g...  Mar 10th, 2009  2009.0
# 2  https://www.techpowerup.com/gpu-specs/nvidia-g...  Jan 20th, 2009  2009.0
# 3  https://www.techpowerup.com/gpu-specs/nvidia-g...  Mar 10th, 2009  2009.0
# 4  https://www.techpowerup.com/gpu-specs/nvidia-g...  Dec 12th, 2008  2008.0
#
#             Bus                  Memory  ... L0 Cache L1 Cache L2 Cache  \
# 0  PCIe 2.0 x16    256 MB, DDR2, 64 bit  ...      NaN      NaN    16 KB
# 1  PCIe 2.0 x16   512 MB, DDR2, 128 bit  ...      NaN      NaN    32 KB
# 2  PCIe 2.0 x16  512 MB, GDDR3, 128 bit  ...      NaN      NaN    32 KB
# 3  PCIe 2.0 x16   512 MB, DDR2, 192 bit  ...      NaN      NaN    64 KB
# 4  PCIe 2.0 x16  512 MB, GDDR3, 192 bit  ...      NaN      NaN    64 KB
#
#   L3 Cache Max. TDP      Pixel Rate    Texture Rate FP16 (half)  FP32 (float)  \
# 0      NaN     40 W  2.160 GPixel/s  2.160 GTexel/s         NaN  20.80 GFLOPS
# 1      NaN     50 W  5.904 GPixel/s  11.81 GTexel/s         NaN  117.5 GFLOPS
# 2      NaN     50 W  4.400 GPixel/s  8.800 GTexel/s         NaN  89.60 GFLOPS
# 3      NaN    105 W  6.000 GPixel/s  12.00 GTexel/s         NaN  120.0 GFLOPS
# 4      NaN    105 W  7.200 GPixel/s  14.40 GTexel/s         NaN  144.0 GFLOPS
#
#    FP64 (double)
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 40 columns]

# %%
from bs4 import BeautifulSoup
import requests
import time 
import random

# %%
def classify_gen(arch):
    
    gpu_details = {
        "Arbitrary Gen": "Unknown",
        "Gen Year": "Unknown"
    }
    
    if arch == "Tesla":
        gpu_details = {
            "Abritary Gen": "1",
            "Gen Year": "2006",
        }
    if arch == "Tesla 2.0":
        gpu_details = {
            "Abritary Gen": "2",
            "Gen Year": "2007",
        }
    if arch == "Fermi":
        gpu_details = {
            "Abritary Gen": "3",
            "Gen Year": "2010",
        }
    if arch == "Fermi 2.0":
        gpu_details = {
            "Abritary Gen": "4",
            "Gen Year": "2011",
        }
    if arch == "Kepler":
        gpu_details = {
            "Abritary Gen": "5",
            "Gen Year": "2012",
        }
    
    if arch == "Kepler 2.0":
        gpu_details = {
            "Abritary Gen": "6",
            "Gen Year": "2013",
        }
    
    if arch == "Maxwell":
        gpu_details = {
            "Abritary Gen": "7",
            "Gen Year": "2014",
        }
    if arch == "Maxwell 2.0":
        gpu_details = {
            "Abritary Gen": "8",
            "Gen Year": "2015",
        }
    if arch == "Pascal":
        gpu_details = {
            "Abritary Gen": "9",
            "Gen Year": "2016",
        }
    if arch == "Volta":
        gpu_details = {
            "Abritary Gen": "10",
            "Gen Year": "2017",
        }
    if arch == "Turing":
        gpu_details = {
            "Abritary Gen": "11",
            "Gen Year": "2018",
        }
    if arch == "Ampere":
        gpu_details = {
            "Abritary Gen": "12",
            "Gen Year": "2020",
        }
    if arch == "Ada Lovelace":
        gpu_details = {
            "Abritary Gen": "13",
            "Gen Year": "2022",
        }
        
    return gpu_details

# %%
iteration = 0
start_index = 0

# %%
# Iterate over the DataFrame and scrape details for each GPU
print(f'the start iteration is {iteration}')
print(f'the start index is {start_index}')
for index, row in gpu_data.loc[start_index:].iterrows():
    iteration += 1
    print(f"the iteration is {iteration}")
    gpu_details = classify_gen(row['Architecture'])
    for key, value in  gpu_details.items():
        gpu_data.at[index, key] = value
  



# Save the updated DataFrame to a new Excel file once all done
updated_file_path = f'Updated_GPU_Dataset{iteration}_Nvidia_gen.xlsx'
gpu_data.to_excel(updated_file_path, index=False)
print(f"Updated dataset saved to {updated_file_path}")
# Out:
# the start iteration is 0
# the start index is 0
# the iteration is 1
# the iteration is 2
# the iteration is 3
# the iteration is 4
# the iteration is 5
# the iteration is 6
# the iteration is 7
# the iteration is 8
# the iteration is 9
# the iteration is 10
# the iteration is 11
# the iteration is 12
# the iteration is 13
# the iteration is 14
# the iteration is 15
# the iteration is 16
# the iteration is 17
# the iteration is 18
# the iteration is 19
# the iteration is 20
# the iteration is 21
# the iteration is 22
# the iteration is 23
# the iteration is 24
# the iteration is 25
# the iteration is 26
# the iteration is 27
# the iteration is 28
# the iteration is 29
# the iteration is 30
# the iteration is 31
# the iteration is 32
# the iteration is 33
# the iteration is 34
# the iteration is 35
# the iteration is 36
# the iteration is 37
# the iteration is 38
# the iteration is 39
# the iteration is 40
# the iteration is 41
# the iteration is 42
# the iteration is 43
# the iteration is 44
# the iteration is 45
# the iteration is 46
# the iteration is 47
# the iteration is 48
# the iteration is 49
# the iteration is 50
# the iteration is 51
# the iteration is 52
# the iteration is 53
# the iteration is 54
# the iteration is 55
# the iteration is 56
# the iteration is 57
# the iteration is 58
# the iteration is 59
# the iteration is 60
# the iteration is 61
# the iteration is 62
# the iteration is 63
# the iteration is 64
# the iteration is 65
# the iteration is 66
# the iteration is 67
# the iteration is 68
# the iteration is 69
# the iteration is 70
# the iteration is 71
# the iteration is 72
# the iteration is 73
# the iteration is 74
# the iteration is 75
# the iteration is 76
# the iteration is 77
# the iteration is 78
# the iteration is 79
# the iteration is 80
# the iteration is 81
# the iteration is 82
# the iteration is 83
# the iteration is 84
# the iteration is 85
# the iteration is 86
# the iteration is 87
# the iteration is 88
# the iteration is 89
# the iteration is 90
# the iteration is 91
# the iteration is 92
# the iteration is 93
# the iteration is 94
# the iteration is 95
# the iteration is 96
# the iteration is 97
# the iteration is 98
# the iteration is 99
# the iteration is 100
# the iteration is 101
# the iteration is 102
# the iteration is 103
# the iteration is 104
# the iteration is 105
# the iteration is 106
# the iteration is 107
# the iteration is 108
# the iteration is 109
# the iteration is 110
# the iteration is 111
# the iteration is 112
# the iteration is 113
# the iteration is 114
# the iteration is 115
# the iteration is 116
# the iteration is 117
# the iteration is 118
# the iteration is 119
# the iteration is 120
# the iteration is 121
# the iteration is 122
# the iteration is 123
# the iteration is 124
# the iteration is 125
# the iteration is 126
# the iteration is 127
# the iteration is 128
# the iteration is 129
# the iteration is 130
# the iteration is 131
# the iteration is 132
# the iteration is 133
# the iteration is 134
# the iteration is 135
# the iteration is 136
# the iteration is 137
# the iteration is 138
# the iteration is 139
# the iteration is 140
# the iteration is 141
# the iteration is 142
# the iteration is 143
# the iteration is 144
# the iteration is 145
# the iteration is 146
# the iteration is 147
# the iteration is 148
# the iteration is 149
# the iteration is 150
# the iteration is 151
# the iteration is 152
# the iteration is 153
# the iteration is 154
# the iteration is 155
# the iteration is 156
# the iteration is 157
# the iteration is 158
# the iteration is 159
# the iteration is 160
# the iteration is 161
# the iteration is 162
# the iteration is 163
# the iteration is 164
# the iteration is 165
# the iteration is 166
# the iteration is 167
# the iteration is 168
# the iteration is 169
# the iteration is 170
# the iteration is 171
# the iteration is 172
# the iteration is 173
# the iteration is 174
# the iteration is 175
# the iteration is 176
# the iteration is 177
# the iteration is 178
# the iteration is 179
# the iteration is 180
# the iteration is 181
# the iteration is 182
# the iteration is 183
# the iteration is 184
# the iteration is 185
# the iteration is 186
# the iteration is 187
# the iteration is 188
# the iteration is 189
# the iteration is 190
# the iteration is 191
# the iteration is 192
# the iteration is 193
# the iteration is 194
# the iteration is 195
# the iteration is 196
# the iteration is 197
# the iteration is 198
# the iteration is 199
# the iteration is 200
# the iteration is 201
# the iteration is 202
# the iteration is 203
# the iteration is 204
# the iteration is 205
# the iteration is 206
# the iteration is 207
# the iteration is 208
# the iteration is 209
# the iteration is 210
# the iteration is 211
# the iteration is 212
# the iteration is 213
# the iteration is 214
# the iteration is 215
# the iteration is 216
# the iteration is 217
# the iteration is 218
# the iteration is 219
# the iteration is 220
# the iteration is 221
# the iteration is 222
# the iteration is 223
# the iteration is 224
# the iteration is 225
# the iteration is 226
# the iteration is 227
# the iteration is 228
# the iteration is 229
# the iteration is 230
# the iteration is 231
# the iteration is 232
# the iteration is 233
# the iteration is 234
# the iteration is 235
# the iteration is 236
# the iteration is 237
# the iteration is 238
# the iteration is 239
# the iteration is 240
# the iteration is 241
# the iteration is 242
# the iteration is 243
# the iteration is 244
# the iteration is 245
# the iteration is 246
# the iteration is 247
# the iteration is 248
# the iteration is 249
# the iteration is 250
# the iteration is 251
# the iteration is 252
# the iteration is 253
# the iteration is 254
# the iteration is 255
# the iteration is 256
# the iteration is 257
# the iteration is 258
# the iteration is 259
# the iteration is 260
# the iteration is 261
# the iteration is 262
# the iteration is 263
# the iteration is 264
# the iteration is 265
# the iteration is 266
# the iteration is 267
# the iteration is 268
# the iteration is 269
# the iteration is 270
# the iteration is 271
# the iteration is 272
# the iteration is 273
# the iteration is 274
# the iteration is 275
# the iteration is 276
# the iteration is 277
# the iteration is 278
# the iteration is 279
# Updated dataset saved to Updated_GPU_Dataset279_Nvidia.xlsx

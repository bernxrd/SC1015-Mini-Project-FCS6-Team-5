# %% [markdown]
# # Import Necessary Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time 
import random
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# # Load Nvidia Excel File Into Data Frame

# %%
# Load the Excel file to see its content and structure
# Marcus edited the file path. Please edit back to yours later

#file_path = r"Updated_GPU_Dataset279_Nvidia_gen.xlsx"
gpu_data = pd.read_excel('Updated_GPU_Dataset279_Nvidia_gen.xlsx') 

# Display the first few rows of the dataframe to understand its structure
gpu_data.head()
# Out:
#   Manufacturer   Generation                Product Name  \
# 0       Nvidia  GeForce 100            GeForce G100 OEM
# 1       Nvidia  GeForce 100          GeForce GT 120 OEM
# 2       Nvidia  GeForce 100  GeForce GT 120 Mac Edition
# 3       Nvidia  GeForce 100          GeForce GT 130 OEM
# 4       Nvidia  GeForce 100  GeForce GT 130 Mac Edition
#
#                                              GPU URL GPU Chip  \
# 0  https://www.techpowerup.com/gpu-specs/geforce-...     G98S
# 1  https://www.techpowerup.com/gpu-specs/geforce-...     G96C
# 2  https://www.techpowerup.com/gpu-specs/geforce-...     G96C
# 3  https://www.techpowerup.com/gpu-specs/geforce-...     G94B
# 4  https://www.techpowerup.com/gpu-specs/geforce-...     G94B
#
#                                             Chip URL        Released    Year  \
# 0  https://www.techpowerup.com/gpu-specs/nvidia-g...  Mar 10th, 2009  2009.0
# 1  https://www.techpowerup.com/gpu-specs/nvidia-g...  Mar 10th, 2009  2009.0
# 2  https://www.techpowerup.com/gpu-specs/nvidia-g...  Jan 20th, 2009  2009.0
# 3  https://www.techpowerup.com/gpu-specs/nvidia-g...  Mar 10th, 2009  2009.0
# 4  https://www.techpowerup.com/gpu-specs/nvidia-g...  Dec 12th, 2008  2008.0
#
#             Bus                  Memory  ... L2 Cache L3 Cache Max. TDP  \
# 0  PCIe 2.0 x16    256 MB, DDR2, 64 bit  ...    16 KB      NaN     40 W
# 1  PCIe 2.0 x16   512 MB, DDR2, 128 bit  ...    32 KB      NaN     50 W
# 2  PCIe 2.0 x16  512 MB, GDDR3, 128 bit  ...    32 KB      NaN     50 W
# 3  PCIe 2.0 x16   512 MB, DDR2, 192 bit  ...    64 KB      NaN    105 W
# 4  PCIe 2.0 x16  512 MB, GDDR3, 192 bit  ...    64 KB      NaN    105 W
#
#        Pixel Rate    Texture Rate FP16 (half)  FP32 (float) FP64 (double)  \
# 0  2.160 GPixel/s  2.160 GTexel/s         NaN  20.80 GFLOPS           NaN
# 1  5.904 GPixel/s  11.81 GTexel/s         NaN  117.5 GFLOPS           NaN
# 2  4.400 GPixel/s  8.800 GTexel/s         NaN  89.60 GFLOPS           NaN
# 3  6.000 GPixel/s  12.00 GTexel/s         NaN  120.0 GFLOPS           NaN
# 4  7.200 GPixel/s  14.40 GTexel/s         NaN  144.0 GFLOPS           NaN
#
#   Abritary Gen  Gen Year
# 0            1      2006
# 1            1      2006
# 2            1      2006
# 3            1      2006
# 4            1      2006
#
# [5 rows x 42 columns]

# %%
#explore the dataset
gpu_data.info()

# You don't need this! When you call .info, it already gives you all the column names and the datatypes
# print("\n")
# print(gpu_data.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 42 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Manufacturer   279 non-null    object
#  1   Generation     279 non-null    object
#  2   Product Name   279 non-null    object
#  3   GPU URL        279 non-null    object
#  4   GPU Chip       279 non-null    object
#  5   Chip URL       279 non-null    object
#  6   Released       279 non-null    object
#  7   Year           277 non-null    float64
#  8   Bus            279 non-null    object
#  9   Memory         279 non-null    object
#  10  GPU clock      279 non-null    object
#  11  Memory clock   279 non-null    object
#  12  Architecture   279 non-null    object
#  13  Foundry        279 non-null    object
#  14  Process Size   279 non-null    object
#  15  Transistors    279 non-null    object
#  16  Density        279 non-null    object
#  17  Die Size       279 non-null    object
#  18  DirectX        279 non-null    object
#  19  OpenGL         279 non-null    float64
#  20  OpenCL         279 non-null    float64
#  21  Vulkan         159 non-null    object
#  22  Shader Model   279 non-null    object
#  23  WDDM           279 non-null    float64
#  24  Tensor Cores   58 non-null     object
#  25  RT Cores       56 non-null     object
#  26  Shading Units  279 non-null    int64
#  27  TMUs           279 non-null    int64
#  28  ROPs           279 non-null    int64
#  29  SM Count       212 non-null    float64
#  30  L0 Cache       0 non-null      float64
#  31  L1 Cache       227 non-null    object
#  32  L2 Cache       279 non-null    object
#  33  L3 Cache       0 non-null      float64
#  34  Max. TDP       278 non-null    object
#  35  Pixel Rate     279 non-null    object
#  36  Texture Rate   279 non-null    object
#  37  FP16 (half)    90 non-null     object
#  38  FP32 (float)   279 non-null    object
#  39  FP64 (double)  237 non-null    object
#  40  Abritary Gen   279 non-null    int64
#  41  Gen Year       279 non-null    int64
# dtypes: float64(7), int64(5), object(30)
# memory usage: 91.7+ KB

# %% [markdown]
# # Helper Functions For Data Cleaning

# %%
def convert_flops(value):
    value = value.replace(",", "")  # Remove commas
    if 'TFLOPS' in value:
        return float(value.replace('TFLOPS', '').strip()) * 1000
    elif 'GFLOPS' in value:
        return float(value.replace('GFLOPS', '').strip())
    else:
        return None  # Just in case there are other formats we haven't considered

def convert_to_mb(size):
    if 'GB' in size:
        # Extract the number and multiply by 1024 to convert GB to MB
        return float(size.replace(' GB', '')) * 1024
    elif 'MB' in size:
        # Just convert MB to float
        return float(size.replace(' MB', ''))
    return None

# %% [markdown]
# # Data Cleaning

# %%
# Apply the convert_flops() to the 'FP32 (float)' column
gpu_data['FP32 (float) in GFLOPS'] = gpu_data['FP32 (float)'].apply(convert_flops)

# Cleaning the 'Memory' column by splitting into size, type, and bus width
gpu_data[['Memory Size', 'Memory Type', 'Bus Width']] = gpu_data['Memory'].str.extract(r'(\d+ GB|\d+ MB), (\w+), (\d+ bit)')

# Convert 'GPU clock' and 'Memory clock' to numeric values
gpu_data['GPU clock (MHz)'] = gpu_data['GPU clock'].str.replace(' MHz', '').astype(float)
gpu_data['Memory clock (MHz)'] = gpu_data['Memory clock'].str.replace(' MHz', '').astype(float)

# Convert 'Process Size' to numeric
gpu_data['Process Size (nm)'] = gpu_data['Process Size'].str.replace(' nm', '').astype(float)

# Convert 'Transistors' to numeric in millions
gpu_data['Transistors (millions)'] = gpu_data['Transistors'].str.replace(' million', '').str.replace(',', '').astype(float)

# Convert 'Density' to numeric
gpu_data['Density (M/mm²)'] = gpu_data['Density'].str.extract(r'([\d\.]+)').astype(float)

# Convert 'Die Size' to numeric
gpu_data['Die Size (mm²)'] = gpu_data['Die Size'].str.replace(' mm²', '').astype(float)

# Remove 'W' from 'Max. TDP' and convert to float
gpu_data['Max. TDP (W)'] = gpu_data['Max. TDP'].str.replace(' W', '').astype(float)

# Remove 'bit' from 'Bus Width' and convert to int
gpu_data['Bus Width (bits)'] = gpu_data['Bus Width'].str.replace(' bit', '').astype(int)

# Cleaning 'Pixel Rate' and 'Texture Rate'
gpu_data['Pixel Rate (GPixel/s)'] = gpu_data['Pixel Rate'].str.replace(' GPixel/s', '').astype(float)
gpu_data['Texture Rate (GTexel/s)'] = gpu_data['Texture Rate'].str.replace(' GTexel/s', '').str.replace(',', '').astype(float)

# Cleaning L2 Cahce
gpu_data['L2 Cache (KB)'] = gpu_data['L2 Cache'].str.replace(' KB', '').astype(float)

# Clean 'OpenGL' and 'OpenCL' version notations by ensuring numeric consistency
gpu_data['OpenGL'] = gpu_data['OpenGL'].astype(float)  # Ensuring all are float
#gpu_data['OpenCL'] = gpu_data['OpenCL'].str.extract(r'(\d+\.\d+)').astype(float)  # Extracting the main version

# Apply the convert_to_mb to the 'Memory Size' column
gpu_data['Memory Size (MB)'] = gpu_data['Memory Size'].apply(convert_to_mb)

gpu_data.dtypes
# Out:
# Manufacturer                object
# Generation                  object
# Product Name                object
# GPU URL                     object
# GPU Chip                    object
# Chip URL                    object
# Released                    object
# Year                       float64
# Bus                         object
# Memory                      object
# GPU clock                   object
# Memory clock                object
# Architecture                object
# Foundry                     object
# Process Size                object
# Transistors                 object
# Density                     object
# Die Size                    object
# DirectX                     object
# OpenGL                     float64
# OpenCL                     float64
# Vulkan                      object
# Shader Model                object
# WDDM                       float64
# Tensor Cores                object
# RT Cores                    object
# Shading Units                int64
# TMUs                         int64
# ROPs                         int64
# SM Count                   float64
# L0 Cache                   float64
# L1 Cache                    object
# L2 Cache                    object
# L3 Cache                   float64
# Max. TDP                    object
# Pixel Rate                  object
# Texture Rate                object
# FP16 (half)                 object
# FP32 (float)                object
# FP64 (double)               object
# Abritary Gen                 int64
# Gen Year                     int64
# FP32 (float) in GFLOPS     float64
# Memory Size                 object
# Memory Type                 object
# Bus Width                   object
# GPU clock (MHz)            float64
# Memory clock (MHz)         float64
# Process Size (nm)          float64
# Transistors (millions)     float64
# Density (M/mm²)            float64
# Die Size (mm²)             float64
# Max. TDP (W)               float64
# Bus Width (bits)             int64
# Pixel Rate (GPixel/s)      float64
# Texture Rate (GTexel/s)    float64
# L2 Cache (KB)              float64
# Memory Size (MB)           float64
# dtype: object

# %%
Nvidia_cleaned = gpu_data[['Manufacturer', 'Foundry', 'Architecture', 'Abritary Gen', 'Gen Year', 'FP32 (float) in GFLOPS', 'Memory Size (MB)', 'Memory Type', 'Bus Width (bits)', 'GPU clock (MHz)', 'Memory clock (MHz)', 'Process Size (nm)', 'Transistors (millions)', 'Density (M/mm²)', 'Die Size (mm²)', 'Max. TDP (W)', 'Pixel Rate (GPixel/s)', 'Texture Rate (GTexel/s)', 'L2 Cache (KB)', 'Shading Units']]
Nvidia_cleaned.info()
Nvidia_cleaned.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Manufacturer             279 non-null    object
#  1   Foundry                  279 non-null    object
#  2   Architecture             279 non-null    object
#  3   Abritary Gen             279 non-null    int64
#  4   Gen Year                 279 non-null    int64
#  5   FP32 (float) in GFLOPS   279 non-null    float64
#  6   Memory Size (MB)         279 non-null    float64
#  7   Memory Type              279 non-null    object
#  8   Bus Width (bits)         279 non-null    int64
#  9   GPU clock (MHz)          279 non-null    float64
#  10  Memory clock (MHz)       279 non-null    float64
#  11  Process Size (nm)        279 non-null    float64
#  12  Transistors (millions)   279 non-null    float64
#  13  Density (M/mm²)          279 non-null    float64
#  14  Die Size (mm²)           279 non-null    float64
#  15  Max. TDP (W)             278 non-null    float64
#  16  Pixel Rate (GPixel/s)    279 non-null    float64
#  17  Texture Rate (GTexel/s)  279 non-null    float64
#  18  L2 Cache (KB)            279 non-null    float64
#  19  Shading Units            279 non-null    int64
# dtypes: float64(12), int64(4), object(4)
# memory usage: 43.7+ KB
#   Manufacturer Foundry Architecture  Abritary Gen  Gen Year  \
# 0       Nvidia     UMC        Tesla             1      2006
# 1       Nvidia    TSMC        Tesla             1      2006
# 2       Nvidia    TSMC        Tesla             1      2006
# 3       Nvidia    TSMC        Tesla             1      2006
# 4       Nvidia    TSMC        Tesla             1      2006
#
#    FP32 (float) in GFLOPS  Memory Size (MB) Memory Type  Bus Width (bits)  \
# 0                    20.8             256.0        DDR2                64
# 1                   117.5             512.0        DDR2               128
# 2                    89.6             512.0       GDDR3               128
# 3                   120.0             512.0        DDR2               192
# 4                   144.0             512.0       GDDR3               192
#
#    GPU clock (MHz)  Memory clock (MHz)  Process Size (nm)  \
# 0            540.0               400.0               65.0
# 1            738.0               504.0               55.0
# 2            550.0               800.0               55.0
# 3            500.0               500.0               55.0
# 4            600.0               792.0               55.0
#
#    Transistors (millions)  Density (M/mm²)  Die Size (mm²)  Max. TDP (W)  \
# 0                   210.0              2.4            86.0          40.0
# 1                   314.0              2.6           121.0          50.0
# 2                   314.0              2.6           121.0          50.0
# 3                   505.0              2.6           196.0         105.0
# 4                   505.0              2.6           196.0         105.0
#
#    Pixel Rate (GPixel/s)  Texture Rate (GTexel/s)  L2 Cache (KB)  \
# 0                  2.160                     2.16           16.0
# 1                  5.904                    11.81           32.0
# 2                  4.400                     8.80           32.0
# 3                  6.000                    12.00           64.0
# 4                  7.200                    14.40           64.0
#
#    Shading Units
# 0              8
# 1             32
# 2             32
# 3             64
# 4             64

# %%
Nvidia_cleaned.to_csv('Nvidia_cleaned.csv')
